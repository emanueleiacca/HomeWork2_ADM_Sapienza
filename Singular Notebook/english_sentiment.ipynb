# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/steam-reviews-2021/steam_reviews.csv

# %%
# !pip install vaderSentiment
# Out:
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from vaderSentiment) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->vaderSentiment) (2024.8.30)
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: vaderSentiment
# Successfully installed vaderSentiment-3.3.2

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import time
import csv

vader_analyzer = SentimentIntensityAnalyzer()

chunksize = 1000000
sentiment_file_path = 'english_sentiment.csv'
file_path = '/kaggle/input/steam-reviews-2021/steam_reviews.csv'

# sentiment analysis using VADER
def vader_sentiment_analysis(text):
    if pd.isna(text):
        return 'neutral'
    score = vader_analyzer.polarity_scores(text)['compound']
    if score >= 0.05:
        return 'positive'
    elif score <= -0.05:
        return 'negative'
    else:
        return 'neutral'

# Start the timer
start_time = time.time()

# Process the file in chunks
for i, chunk in enumerate(pd.read_csv(file_path, chunksize=chunksize, encoding='utf-8', 
                                      quoting=csv.QUOTE_MINIMAL, escapechar='\\', 
                                      on_bad_lines='skip', low_memory=False, dtype=str)):

    chunk = chunk[chunk['language'] == 'english'].copy()
    chunk['sentiment'] = chunk['review'].apply(lambda x: vader_sentiment_analysis(x))
    sentiment_chunk = chunk[['review_id', 'review', 'sentiment']]

    # Log 
    elapsed_time = time.time() - start_time
    print(f"\n--- Chunk {i + 1} processed ---")
    print(f"Time taken for this chunk: {elapsed_time:.2f} seconds")
    print(f"Sample of sentiment data:\n{sentiment_chunk.head()}\n")

    # Overwrite original file
    mode = 'w' if i == 0 else 'a' # w: "write" for the first chunk, a "append" for the next
    header = i == 0
    sentiment_chunk[['review_id','review', 'sentiment']].to_csv(sentiment_file_path, mode=mode, header=header, index=False)

# Calculate total time taken
total_time = time.time() - start_time
print(f"\n=== Total time taken for processing all chunks: {total_time:.2f} seconds ===")
# Out:
# --- Chunk 1 processed ---
# Time taken for this chunk: 286.05 seconds
# Sample of sentiment data:
#    review_id                                             review sentiment
# 3   85184605  One of the best RPG's of all time, worthy of a...  positive
# 5   85184171             good story, good graphics. lots to do.  positive
# 6   85184064                                           dis gud,   neutral
# 18  85180436  favorite game of all time cant wait for the Ne...  positive
# 20  85179753                          Why wouldn't you get this   neutral
#
#
# --- Chunk 2 processed ---
# Time taken for this chunk: 551.36 seconds
# Sample of sentiment data:
#         review_id                          review sentiment
# 1000000  71818717                             fun  positive
# 1000002  71818514                         plese\n   neutral
# 1000005  71818242                       very good  positive
# 1000006  71818234                       good game  positive
# 1000007  71818218  Hm.. It's a good game I think,  positive
#
#
# --- Chunk 3 processed ---
# Time taken for this chunk: 1101.13 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 2000001  46547800  Fucking shit, community campers 0 skills, 0 ba...  negative
# 2000003  46547658                                               Cool  positive
# 2000019  46546491  great game to play with friends as long as you...  positive
# 2000021  46546237  run noed v swf and laugh at them when they get...  positive
# 2000034  46544499  Dead by Daylight is a horror game that is more...  positive
#
#
# --- Chunk 4 processed ---
# Time taken for this chunk: 1815.95 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 3000000  13729676                                rust with cannibals   neutral
# 3000002  13728822  Keeping in mind it is a Beta, its pretty decen...  positive
# 3000003  13728787                               Really awesome 10/10  positive
# 3000004  13728316          Malaysia Airlines Simulator 2014\n\n10/10   neutral
# 3000005  13728286                                   Its a good game!  positive
#
#
# --- Chunk 5 processed ---
# Time taken for this chunk: 2165.45 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 4000001  49295258  패치 됐다해서 오랜만에 접속하니까 프레임 시1발 떡락ㅋㅋㅋㅋ\n아시아 서버는 어디다...   neutral
# 4000002  49294987     FUCK THIS GAME IS ASS UPDATE THIS GAME IT  BAD  negative
# 4000003  49294780  Stutter city, stay away. Patches every 3 month...  negative
# 4000006  49294669  Bad animations, bad weapons, bad hit reg, bad ...  negative
# 4000007  49294355  EDIT: As of the 1.71 Update I can continue to ...  positive
#
#
# --- Chunk 6 processed ---
# Time taken for this chunk: 2704.65 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 5000001  73975565           Really fun game to play with a friends\n  positive
# 5000003  73975476  What happens when you put an edgy teenager gir...  negative
# 5000004  73975460                         excellent quality AAA game  positive
# 5000009  73974404  I'll try to make my comment succinct. In short...  negative
# 5000010  73974332  Im a big fan of Destiny and this is just like ...  positive
#
#
# --- Chunk 7 processed ---
# Time taken for this chunk: 2929.54 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 6000002  72009767                                          good game  positive
# 6000003  72009765                                   This game is OK.   neutral
# 6000009  72009339  Pretty diverse agents with really cool ability...  positive
# 6000011  72009225               I have played more R6 than Destiny 2  positive
# 6000014  72008878                                          Nice Game  positive
#
#
# --- Chunk 8 processed ---
# Time taken for this chunk: 3300.27 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 7000003  76899123                                    me me big boy\n   neutral
# 7000004  76899079                                         it aight\n   neutral
# 7000005  76899075  Its funn but there are some purple who leavs  ...   neutral
# 7000006  76899071  Amazing game with friends. Free on mobile but ...  positive
# 7000008  76899051                              Very fun with friends  positive
#
#
# --- Chunk 9 processed ---
# Time taken for this chunk: 3701.76 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 8000000  59383375                                          its guuud   neutral
# 8000001  59383343  It's beyond unique and quite fun, a bit repeti...  positive
# 8000002  59383212       Very addicting and unlimited possibilities\n   neutral
# 8000003  59383164  Great game the most recent update has really g...  positive
# 8000004  59383119                                                yes  positive
#
#
# --- Chunk 10 processed ---
# Time taken for this chunk: 4138.15 seconds
# Sample of sentiment data:
#         review_id                                             review sentiment
# 9000001  49906043  I laf at myself for crying about the price now...  negative
# 9000002  49905099  1 Acronym...... \n.\n.\n.\n.\n.\n.\n.\n.\n.\n....   neutral
# 9000006  49903186  I still havent been able to finish the game, l...   neutral
# 9000007  49902101  After RE7 I had low expectations and they were...  positive
# 9000008  49899923  this game is so fucking good and scary  ihighl...   neutral
#
#
# --- Chunk 11 processed ---
# Time taken for this chunk: 4615.72 seconds
# Sample of sentiment data:
#          review_id                  review sentiment
# 10000000  52949639                     hud   neutral
# 10000001  52949517     best game, much fun  positive
# 10000003  52949491         Very good game!  positive
# 10000004  52949400  I am feeling thank you  positive
# 10000006  52949268                     pog   neutral
#
#
# --- Chunk 12 processed ---
# Time taken for this chunk: 5072.70 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 11000001  80105824  Be prepared for a lot of moral conflicts. Simp...
# 11000003  80103537                                     Good old game!
# 11000004  80088760  Very fun. Have done a couple different playthr...
# 11000006  80080670  Deny all their visas to make Arstotzka great a...
# 11000008  80051858  A unique and fun experience! This game challen...
#
#          sentiment
# 11000001  positive
# 11000003  positive
# 11000004  positive
# 11000006  positive
# 11000008  positive
#
#
# --- Chunk 13 processed ---
# Time taken for this chunk: 5581.28 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 12000001  43500880  one of those games where you won't stick aroun...
# 12000002  43499838  the engine for this game is amazing, epic cras...
# 12000003  43499114  This game is awesome. I have over 600 hours on...
# 12000004  43497761  Hands down the best soft body physics based si...
# 12000005  43496486                                              smosh
#
#          sentiment
# 12000001   neutral
# 12000002  positive
# 12000003  positive
# 12000004  positive
# 12000005   neutral
#
#
# --- Chunk 14 processed ---
# Time taken for this chunk: 5809.47 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 13000001  65829033  Left Handed Key Binding not supported.  In par...
# 13000002  65829014  Modders ruin the game entirely, don't ever get...
# 13000003  65828908                                Graphics!\nStory!\n
# 13000007  65828800            There are a lot of hackers in this game
# 13000009  65828791                                              iykyk
#
#          sentiment
# 13000001  negative
# 13000002  negative
# 13000003   neutral
# 13000007   neutral
# 13000009   neutral
#
#
# --- Chunk 15 processed ---
# Time taken for this chunk: 5956.34 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 14000019  68541179  Gun-play is nice, that's about it.\nPretty bor...
# 14000023  68541135        Would be a good game if they added building
# 14000024  68541130                Wish the graphics were a bit better
# 14000026  68541111  I got banned for no reason on PUBG after a yea...
# 14000061  68539998                                             nice\n
#
#          sentiment
# 14000019  positive
# 14000023  positive
# 14000024  positive
# 14000026  negative
# 14000061  positive
#
#
# --- Chunk 16 processed ---
# Time taken for this chunk: 6400.75 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 15000000  37869472  Ban for nothing, n1. Deleting game and back fo...
# 15000001  37869435  i loved this game but it will be uninstalled u...
# 15000002  37869405                                         good game.
# 15000003  37869393  Trash game\n1. too many fcuking chinese\n2. ch...
# 15000009  37869304                                          Nice su~!
#
#          sentiment
# 15000000  negative
# 15000001   neutral
# 15000002  positive
# 15000003   neutral
# 15000009  positive
#
#
# --- Chunk 17 processed ---
# Time taken for this chunk: 7356.73 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 16000001  25324123  Beautiful and very fun game. Becomes even more...
# 16000003  25323503  Solid city builder with a great modding commun...
# 16000005  25323281                                        great game.
# 16000006  25322807             Great game having so much fun with it.
# 16000007  25322782  I absolutely adore this game. Expanding your c...
#
#          sentiment
# 16000001  positive
# 16000003  positive
# 16000005  positive
# 16000006  positive
# 16000007  positive
#
#
# --- Chunk 18 processed ---
# Time taken for this chunk: 8178.77 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 17000001  46146911                                                yis
# 17000002  46146384                                             10/10!
# 17000003  46146330                               Fun times with snow.
# 17000007  46144913  From the makers of "This War of Mine" a game w...
# 17000013  46143534  Frostpunk is my 2018 game of the year for simp...
#
#          sentiment
# 17000001   neutral
# 17000002   neutral
# 17000003  positive
# 17000007  positive
# 17000013  positive
#
#
# --- Chunk 19 processed ---
# Time taken for this chunk: 8542.06 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 18000004  41592954  As a huge RTS fan, I love it. People complaini...
# 18000005  41592908  Game is harder then you think, and I enjoy it....
# 18000008  41587235  This game is pretty great.  Lots of fun.   Lik...
# 18000010  41583800  horrible campainge just blank and uninspired t...
# 18000012  41579809           Very Fun! I can't wait for more updates.
#
#          sentiment
# 18000004  positive
# 18000005  positive
# 18000008  positive
# 18000010  negative
# 18000012  positive
#
#
# --- Chunk 20 processed ---
# Time taken for this chunk: 9149.20 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 19000000  10463389                 you can but TNT on a bunny. 100/10
# 19000005  10462664                                               Good
# 19000006  10462529                                            EPIC!!!
# 19000007  10462307  This game just never gets old for me. The devs...
# 19000008  10462288  Fun, retro-ish world. Lots of doing-whatever-t...
#
#          sentiment
# 19000000   neutral
# 19000005  positive
# 19000006   neutral
# 19000007  positive
# 19000008  positive
#
#
# --- Chunk 21 processed ---
# Time taken for this chunk: 9981.51 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 20000001  67561550  I am not even going to try to do a detailed an...
# 20000002  67561537                                   All time classic
# 20000003  67560539                          Excellent game. Timeless!
# 20000004  67560386  The best graphics in a game I've ever seen & t...
# 20000006  67559854  It's freaking Skyrim. If you call yourself a g...
#
#          sentiment
# 20000001  positive
# 20000002   neutral
# 20000003  positive
# 20000004  positive
# 20000006  negative
#
#
# --- Chunk 22 processed ---
# Time taken for this chunk: 10575.67 seconds
# Sample of sentiment data:
#          review_id                                             review  \
# 21000000  83171859                           this game is alot of fun
# 21000001  83171269                                        its awesome
# 21000007  83165773                           Its good and fun to play
# 21000008  83164980  Great Game! Way better than Roller Coaster Tyc...
# 21000009  83160129                                              er5dt
#
#          sentiment
# 21000000  positive
# 21000001  positive
# 21000007  positive
# 21000008  positive
# 21000009   neutral
#
#
# === Total time taken for processing all chunks: 10581.71 seconds ===
